# %%
from pathlib import Path
import os

print("Current working directory:")
print(os.getcwd())

print("\nFiles:")
print(list(Path(".").iterdir())[:10])

# %%
from google.colab import drive

drive.mount("/content/drive")

# %%
from pathlib import Path

OUTPUT_ROOT = Path("/content/drive/MyDrive/infinia_outputs")

REFERENCE_DIR = OUTPUT_ROOT / "references"
GENERATED_DIR = OUTPUT_ROOT / "generated"
RESULTS_DIR = OUTPUT_ROOT / "results"

REFERENCE_DIR.mkdir(parents=True, exist_ok=True)
GENERATED_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

print("Output folders are ready.")

# %%
from pathlib import Path
import soundfile as sf
from IPython.display import Audio

REFERENCE_AUDIO = (
    Path("audio")
    / "references"
    / "english"
    / "librispeech_reference.wav"
)

audio, sr = sf.read(REFERENCE_AUDIO)

print("Sample Rate:", sr)
print("Samples:", len(audio))

Audio(audio, rate=sr)
